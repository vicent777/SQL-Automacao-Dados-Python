# %%
# pesquisar google dados gov dados publicos
# https://dados.gov.br/dados/conjuntos-dados
# Defesa e segurança Formato Json

"""
Sites de visualizações Json 
pesquisar no google 
Exemplos
https://jsonviewer.stack.hu/
https://jsonformatter.org/json-viewer
https://codebeautify.org/jsonviewer

e muito mais disponiveis 
"""

# %%
import pandas as pd

# caminho  JSON
Arquivo = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.json"
df =pd.read_json(Arquivo)
df.head(5)
# Out:
#    Numero_da_Ocorrencia Numero_da_Ficha  \
# 0                 33947      2022722007
# 1                 29123       202140534
# 2                 32189      2022293670
# 3                 32190      2022354545
# 4                 32726      2022125796
#
#                         Operador_Padronizado Classificacao_da_Ocorrência  \
# 0        AZUL LINHAS AÉREAS BRASILEIRAS S.A.                   Incidente
# 1                                       AZUL             Incidente Grave
# 2         FIGUEIREDO AVIAÇÃO AGRÍCOLA EIRELI             Incidente Grave
# 3                   FENIX PARTICIPACOES LTDA                   Incidente
# 4  ANAPE EMPREENDIMENTOS IMOBILIÁRIOS-EIRELI                   Incidente
#
#   Data_da_Ocorrencia Hora_da_Ocorrência      Municipio  UF        Regiao  \
# 0         2022-08-11           05:31:00         PALMAS  TO         Norte
# 1         2021-08-06              16:59  CAXIAS DO SUL  RS           Sul
# ...

# %%
import os
#ver tamanho do arquivo 
caminho_arquivo = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.json"
if os.path.exists(caminho_arquivo):
    tamanho = os.path.getsize(caminho_arquivo)
    print(f" {tamanho} bytes")
# Out:
#  20436383 bytes

# %%
import os

caminho_arquivo = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.json"


if os.path.exists(caminho_arquivo):  
    tamanho_bytes = os.path.getsize(caminho_arquivo)        
    # Megabytes (1 MB = 1.048576 bytes)
    tamanho_mb = tamanho_bytes / (1024 * 1024)
    # Converta para gigabytes (1 GB = 1024 MB)
    tamanho_gb = tamanho_mb / 1024
    
    print(f"{tamanho_bytes} bytes")
    print(f"{tamanho_mb:.2f} MB")
    print(f"{tamanho_gb:.2f} GB")
else:
    print("O arquivo não existe")
# Out:
# 20436383 bytes
# 19.49 MB
# 0.02 GB

# %% [markdown]
# https://convertlive.com/pt/u/converter/gigabytes/em/megabytes#1\
# https://www.to-convert.com/pt/informatica/converter-byte-para-megabyte.php

# %% [markdown]
# Fazendo na pratica

# %%
import pandas as pd
import os

# %%
# ler jason
Arquivo = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.json"
df=pd.read_json(Arquivo)
#df.head(5)

# %%
#salvar em parquet
caminho_parquet = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.parquet"
df.to_parquet(caminho_parquet, index=False)

# %%
# Salvar em  CSV
caminho_csv = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.csv"
df.to_csv(caminho_csv, index=False)

# %%
# Salvar em  excel
caminho_excel = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.xlsx"
df.to_excel(caminho_excel, index=False)

# %% [markdown]
# Tamanho Json

# %%
Json = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.json"

# Verifique se o arquivo existe
if os.path.exists(Json):
    tamanho_bytes = os.path.getsize(Json)     
    tamanho_mb = tamanho_bytes / (1024 * 1024)
    tamanho_gb = tamanho_mb / 1024
    
    print(f" {tamanho_bytes} bytes")
    print(f" {tamanho_mb:.2f} MB")
    print(f" {tamanho_gb:.2f} GB")
else:
    print("O arquivo não existe.")
# Out:
#  20436383 bytes
#  19.49 MB
#  0.02 GB

# %% [markdown]
# Tamanho Parquet

# %%
parquet = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.parquet"

# Verifique se o arquivo existe
if os.path.exists(parquet):
    tamanho_bytes = os.path.getsize(parquet)     
    tamanho_mb = tamanho_bytes / (1024 * 1024)
    tamanho_gb = tamanho_mb / 1024
    
    print(f" {tamanho_bytes} bytes")
    print(f" {tamanho_mb:.2f} MB")
    print(f" {tamanho_gb:.2f} GB")
else:
    print("O arquivo não existe.")
# Out:
#  3339103 bytes
#  3.18 MB
#  0.00 GB

# %%
csv = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.csv"

# Verifique se o arquivo existe
if os.path.exists(csv):
    tamanho_bytes = os.path.getsize(csv)     
    tamanho_mb = tamanho_bytes / (1024 * 1024)
    tamanho_gb = tamanho_mb / 1024
    
    print(f" {tamanho_bytes} bytes")
    print(f" {tamanho_mb:.2f} MB")
    print(f" {tamanho_gb:.2f} GB")
else:
    print("O arquivo não existe.")
# Out:
#  8788888 bytes
#  8.38 MB
#  0.01 GB

# %%
excel = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.xlsx"

# Verifique se o arquivo existe
if os.path.exists(excel):
    tamanho_bytes = os.path.getsize(excel)     
    tamanho_mb = tamanho_bytes / (1024 * 1024)
    tamanho_gb = tamanho_mb / 1024
    
    print(f" {tamanho_bytes} bytes")
    print(f" {tamanho_mb:.2f} MB")
    print(f" {tamanho_gb:.2f} GB")
else:
    print("O arquivo não existe.")
# Out:
#  4916858 bytes
#  4.69 MB
#  0.00 GB

# %%
import os
import pandas as pd

# Caminho dos arquivos
caminho_csv = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\2.Diferentes+Arquivos.ipynb"
caminho_parquet = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.parquet"
caminho_json = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.json"
caminho_excel = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.xlsx"

#lista arquivos para fazer o for looop
caminhos_arquivos = [caminho_csv, caminho_parquet, caminho_json, caminho_excel]

# listavazia tamanhos
tamanhos_bytes = []
tamanhos_mb = []
tamanhos_gb = []

# Loop através dos caminhos dos arquivos
for caminho_arquivo in caminhos_arquivos:
    if os.path.exists(caminho_arquivo):
        tamanho_bytes = os.path.getsize(caminho_arquivo)
        tamanho_mb = tamanho_bytes / (1024 * 1024)
        tamanho_gb = tamanho_mb / 1024
        
        tamanhos_bytes.append(tamanho_bytes)
        tamanhos_mb.append(tamanho_mb)
        tamanhos_gb.append(tamanho_gb)
    else:
        tamanhos_bytes.append(None)
        tamanhos_mb.append(None)
        tamanhos_gb.append(None)

# levando para DF
data = {
    'Arquivo': caminhos_arquivos,
    'Bytes': tamanhos_bytes,
    'MB': tamanhos_mb,
    'GB': tamanhos_gb
}
dftamanho = pd.DataFrame(data)

dftamanho.head()
# Out:
#                                              Arquivo     Bytes         MB  \
# 0  C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Mod...     36917   0.035207
# 1  C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Mod...   3339103   3.184417
# 2  C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Mod...  20436383  19.489654
# 3  C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Mod...   4916858   4.689081
#
#          GB
# 0  0.000034
# 1  0.003110
# 2  0.019033
# 3  0.004579

# %% [markdown]
# ##### Exibindo Parquet no Power BI

# %%
#ler arquivo parquet
import pandas as pd
Caminho = r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.parquet"
dfpq=pd.read_parquet(Caminho)
dfpq.head(5)

## tem como ver Parquet em Power BI queridinho do momento?
# Out:
#    Numero_da_Ocorrencia Numero_da_Ficha  \
# 0                 33947      2022722007
# 1                 29123       202140534
# 2                 32189      2022293670
# 3                 32190      2022354545
# 4                 32726      2022125796
#
#                         Operador_Padronizado Classificacao_da_Ocorrência  \
# 0        AZUL LINHAS AÉREAS BRASILEIRAS S.A.                   Incidente
# 1                                       AZUL             Incidente Grave
# 2         FIGUEIREDO AVIAÇÃO AGRÍCOLA EIRELI             Incidente Grave
# 3                   FENIX PARTICIPACOES LTDA                   Incidente
# 4  ANAPE EMPREENDIMENTOS IMOBILIÁRIOS-EIRELI                   Incidente
#
#   Data_da_Ocorrencia Hora_da_Ocorrência      Municipio  UF        Regiao  \
# 0         2022-08-11           05:31:00         PALMAS  TO         Norte
# 1         2021-08-06              16:59  CAXIAS DO SUL  RS           Sul
# ...

# %% [markdown]
# ##### Arquivo Zipado

# %%
import pandas as pd
import zipfile
import os

df=pd.read_json(r"C:\Users\TERRA\JAVA\dio-java-basico\udemy1\Modulo_bonus\V_OCORRENCIA_AMPLA.json")

pasta_destino = r"C:\Users\edmil\Downloads"
nome_arquivo_parquet = "OcorrenciaANAC.parquet"
caminho_parquet = f"{pasta_destino}/{nome_arquivo_parquet}"

df.to_parquet(caminho_parquet, index=False)

# Nome do arquivo ZIP de saída
nome_arquivo_zip = "OcorrenciaANAC.zip"
caminho_zip = f"{pasta_destino}/{nome_arquivo_zip}"

# Crie um arquivo ZIP contendo o arquivo Parquet
with zipfile.ZipFile(caminho_zip, 'w', compression=zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(caminho_parquet, nome_arquivo_parquet)
    
os.remove(caminho_parquet)  # comando para apagar o arquivo e deixar somente o Zip

# %% [markdown]
# ##### Como Ler arquivo Zipado

# %%
import pandas as pd
import zipfile


#Obs: arquivo Parquet não é extraído para a máquina local e armazenado no DataFrame

PastaZip = r"C:\Users\edmil\Downloads\OcorrenciaANAC.zip"
NomeArquivo = "OcorrenciaANAC.parquet"

# Extrair o arquivo Parquet do arquivo ZIP
with zipfile.ZipFile(PastaZip, 'r') as zipf:
    with zipf.open(NomeArquivo) as Extraido:
        # Transformar Arquivo em um df (pode ser qualqer origem csv, json etc....)
        dfnovo = pd.read_parquet(Extraido)

dfnovo.head(10)
# Out:
#    Numero_da_Ocorrencia Numero_da_Ficha  \
# 0                 33947      2022722007
# 1                 29123       202140534
# 2                 32189      2022293670
# 3                 32190      2022354545
# 4                 32726      2022125796
# 5                 33267      2022814112
# 6                 35928      2023813602
# 7                 36149      2023689258
# 8                 36206      2023101831
# 9                 36206      2023101831
#
#                                 Operador_Padronizado  \
# 0                AZUL LINHAS AÉREAS BRASILEIRAS S.A.
# 1                                               AZUL
# 2                 FIGUEIREDO AVIAÇÃO AGRÍCOLA EIRELI
# 3                           FENIX PARTICIPACOES LTDA
# 4          ANAPE EMPREENDIMENTOS IMOBILIÁRIOS-EIRELI
# 5                                     LATAM Airlines
# 6            SIMOL EMPREENDIMENTOS IMOBILIARIOS LTDA
# 7                AZUL LINHAS AÉREAS BRASILEIRAS S.A.
# ...
